# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/newdata/Credit card transactions.csv
# /kaggle/input/analyzing-credit-card-spending-habits-in-india/Credit card transactions - India - Simple.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
data=pd.read_csv("/kaggle/input/newdata/Credit card transactions.csv")

# %% [markdown]
# # **Checking the dataset**

# %%
# Check the size of the dataset
data.shape
# Out:
# (26052, 7)

# %% [markdown]
# This dataset has 26052 Rows and 7 Columns

# %%
# Get top 5 rows
data.head()
# Out:
#    index                   City       Date  Card Type Exp Type Gender  Amount
# 0      0           Delhi, India  29-Oct-14       Gold    Bills      F   82475
# 1      1  Greater Mumbai, India  22-Aug-14   Platinum    Bills      F   32555
# 2      2       Bengaluru, India  27-Aug-14     Silver    Bills      F  101738
# 3      3  Greater Mumbai, India  12-Apr-14  Signature    Bills      F  123424
# 4      4       Bengaluru, India   5-May-15       Gold    Bills      F  171574

# %% [markdown]
# Column Names are:
# * index - index
# * City - The city in which the transaction took place
# * Date - The date of the transaction
# * Card Type - The type of credit card used for the transaction (Gold, Platinum, Silver, Signature)
# * Exp Type - The type of expense associated with the transaction (Bills, Food, Entertainment, Grocery, Fuel, Travel)
# * Gender - The gender of the cardholder (Male, Female)
# * Amount - The amount of the transaction

# %%
# Check for null values
data.isnull().sum()
# Out:
# index        0
# City         0
# Date         0
# Card Type    0
# Exp Type     0
# Gender       0
# Amount       0
# dtype: int64

# %% [markdown]
# There is no null values

# %%
# Checking for duplicate
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicates

# %% [markdown]
# ## **Date Feature Engineering**

# %%
# Spliting City into City and Country and taking only City
data["City"]=data["City"].str.split(",",expand=True)[0]

# %% [markdown]
# ----

# %%
# Extract Month and Day from the datetime object
data["Date"] = pd.to_datetime(data["Date"], format='%d-%b-%y')
data["Month"] = data["Date"].dt.month
data["Day"] = data["Date"].dt.dayofweek
data["MonthName"] = data["Date"].dt.month_name()
data["DayName"] = data["Date"].dt.day_name()
data["Year"] = data["Date"].dt.year
data.head()
# Out:
#    index            City       Date  Card Type Exp Type Gender  Amount  Month  \
# 0      0           Delhi 2014-10-29       Gold    Bills      F   82475     10
# 1      1  Greater Mumbai 2014-08-22   Platinum    Bills      F   32555      8
# 2      2       Bengaluru 2014-08-27     Silver    Bills      F  101738      8
# 3      3  Greater Mumbai 2014-04-12  Signature    Bills      F  123424      4
# 4      4       Bengaluru 2015-05-05       Gold    Bills      F  171574      5
#
#    Day MonthName    DayName  Year
# 0    2   October  Wednesday  2014
# 1    4    August     Friday  2014
# 2    2    August  Wednesday  2014
# 3    5     April   Saturday  2014
# 4    1       May    Tuesday  2015

# %%
print(f"Number of unique values in Day column: {data['Day'].unique().size}")
print(f"Number of unique values in Month column: {data['Month'].unique().size}")
# Out:
# Number of unique values in Day column: 7
# Number of unique values in Month column: 12

# %% [markdown]
# Since this will also contribute to the complexity of the model, We will reduce the model complexity using cyclic encoding

# %% [markdown]
# ### Cyclic encoding

# %% [markdown]
# Why Cyclic Encoding? <br>
# * Unlike one-hot encoding, cyclical encoding ensures that adjacent cyclical values retain their relationships (e.g., December is adjacent to January). <br>
# * Cyclical encoding requires fewer dimensions than one-hot encoding, leading to more efficient data representation

# %%
def encodeCyclic(value, maxValue):
    radians = 2 * np.pi * value / maxValue
    return np.sin(radians), np.cos(radians)

data['MonthSin'], data['MonthCos'] = zip(*data['Month'].apply(lambda x: encodeCyclic(x-1, 12)))

data['DaySin'], data['DayCos'] = zip(*data['Day'].apply(lambda x: encodeCyclic(x, 7)))

# %%
plt.plot(data['MonthSin'],data['MonthCos'],marker = 'o',markersize = 10, linewidth = 0)
plt.title('Month Cyclic Encoded')
plt.show()

# %%
plt.plot(data['DaySin'],data['DayCos'],marker = 'o',markersize = 10, linewidth = 0)
plt.title('Day Cyclic Encoded')
plt.show()

# %% [markdown]
# ----

# %%
print(f"Number of unique values in City column: {data['City'].unique().size}")
# Out:
# Number of unique values in City column: 986

# %% [markdown]
# Since there are 986 values in the city column it will increase the complexity of the model even more leading to overfitting. To avoid that we are going to use city encoding into tiers.

# %% [markdown]
# ### Encoding Cities into Tiers

# %% [markdown]
# The spending paterns are affected by the city/town in which the customer lives. For example a person from highly developed city with high gross income per person will use thier credit card more, meanwhile a person from under developed city may not even know what a credit card is.

# %% [markdown]
# The classification of Indian cities is a ranking system used by the Government of India to allocate House Rent Allowance (HRA) to public servants employed in cities in India. India has been divided into various categories by the **Pay Commission**. There has been multiple types of classifications.
#
# **Tier Classification:** RBI classifies the cities under Tier 1-6 categories based on their population.
# ![image.png](attachment:8b9cebd5-7be5-4afd-9b81-a1120112ba32.png)
#
# **Rural, Urban classifications:** <br>
# ![image.png](attachment:097ee65e-72d7-4a51-9eac-90a895be61aa.png)
#
# Before 2008, there were two categories in which the cities were classified in India. This was called the Historical classification and the cities were classified before the Sixth Pay Commission's recommendations.
#
# **HRA classification:**
#
# Under the recommendation of the Seventh Central Pay Commission, the CCA classification was abolished in 2008. The earlier HRA classification of cities was changed from
# *     A-1 to X
# *     A, B-1, and B-2 to Y
# *     C and unclassified cities to Z
#
# X, Y, and Z are more commonly known as Tier-1, Tier-2, and Tier-3 cities,
#
# There are eight X cities and 97 Y cities in India.
# ![image.png](attachment:073f2d25-3ca2-46cd-af74-6942e2da644f.png)
#
# References -
# * https://en.wikipedia.org/wiki/Classification_of_Indian_cities
# * https://www.jagranjosh.com/general-knowledge/explained-classification-of-indian-cities-into-tiers-reason-categorization-and-other-details-1629375309-1
#
# Suggestion - Dr. Damayanthi

# %%
t1=['Ahmedabad', 'Bengaluru', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai', 'Pune']
t2=['Ajmer','Aligarh','Amravati','Amritsar','Anand','Asansol','Aurangabad','Bareilly','Belagavi','Bhavnagar','Bhiwandi','Bhopal','Bhubaneswar','Bikaner','Bilaspur','Bokaro Steel City','Burdwan','Chandigarh','Coimbatore','Cuttack','Dahod','Dehradun','Dombivli','Dhanbad','Bhilai','Durgapur','Erode','Faridabad','Ghaziabad','Gorakhpur','Guntur','Gurugram','Guwahati','Gwalior','Hamirpur','Hubli-Dharwad','Indore','Jabalpur','Jaipur','Jalandhar','Jalgaon','Jammu','Jamnagar','Jamshedpur','Jhansi','Jodhpur','Kalaburagi','Kakinada','Kannur','Kanpur','Karnal','Kochi','Kolhapur','Kollam','Kozhikode','Kurnool','Ludhiana','Lucknow','Madurai','Malappuram','Mathura','Mangaluru','Meerut','Moradabad','Mysore','Nagpur','Nanded-Waghala','Nashik','Nellore','Noida','Patna','Puducherry','Purulia','Prayagraj','Raipur','Rajkot','Rajahmundry','Ranchi','Rourkela','Ratlam','Salem','Sangli','Shimla','Siliguri','Solapur','Srinagar','Surat','Thanjavur','Thiruvananthapuram','Thrissur','Tiruchirappalli','Tirunelveli','Tiruvannamalai','Ujjain','Vijayapura','Vadodara','Varanasi','Vasai-Virar','Vijayawada','Visakhapatnam','Vellore','Warangal']

def city_tier(city):
  if city in t1:
    return 'Tier-1'
  elif city in t2:
    return 'Tier-2'
  else :
    return 'Tier-3'

data['City'] = data['City'].apply(lambda x: x.split(',')[0])
data['City Tier'] = data['City'].apply(lambda x: city_tier(x))

# %%
print(f"Number of unique values in City column: {data['City Tier'].unique().size}")
# Out:
# Number of unique values in City column: 3

# %% [markdown]
# Now, 986 values are reduced to 3 values and this will improve the model performance.

# %%
data.head()
# Out:
#    index            City       Date  Card Type Exp Type Gender  Amount  Month  \
# 0      0           Delhi 2014-10-29       Gold    Bills      F   82475     10
# 1      1  Greater Mumbai 2014-08-22   Platinum    Bills      F   32555      8
# 2      2       Bengaluru 2014-08-27     Silver    Bills      F  101738      8
# 3      3  Greater Mumbai 2014-04-12  Signature    Bills      F  123424      4
# 4      4       Bengaluru 2015-05-05       Gold    Bills      F  171574      5
#
#    Day MonthName    DayName  Year  MonthSin      MonthCos    DaySin    DayCos  \
# 0    2   October  Wednesday  2014 -1.000000 -1.836970e-16  0.974928 -0.222521
# 1    4    August     Friday  2014 -0.500000 -8.660254e-01 -0.433884 -0.900969
# 2    2    August  Wednesday  2014 -0.500000 -8.660254e-01  0.974928 -0.222521
# 3    5     April   Saturday  2014  1.000000  6.123234e-17 -0.974928 -0.222521
# 4    1       May    Tuesday  2015  0.866025 -5.000000e-01  0.781831  0.623490
#
#   City Tier
# 0    Tier-1
# 1    Tier-3
# 2    Tier-1
# 3    Tier-3
# 4    Tier-1

# %%
data.drop(columns=["Date","index"], inplace=True)

# %%
data
# Out:
#                  City  Card Type Exp Type Gender  Amount  Month  Day  \
# 0               Delhi       Gold    Bills      F   82475     10    2
# 1      Greater Mumbai   Platinum    Bills      F   32555      8    4
# 2           Bengaluru     Silver    Bills      F  101738      8    2
# 3      Greater Mumbai  Signature    Bills      F  123424      4    5
# 4           Bengaluru       Gold    Bills      F  171574      5    1
# ...               ...        ...      ...    ...     ...    ...  ...
# 26047         Kolkata     Silver   Travel      F  128191      6    6
# 26048            Pune  Signature   Travel      M  246316      8    6
# 26049       Hyderabad     Silver   Travel      M  265019      1    4
# 26050          Kanpur     Silver   Travel      M   88174      9    6
# 26051       Hyderabad  Signature    Bills      M  184410     10    5
#
#        MonthName    DayName  Year  MonthSin      MonthCos    DaySin    DayCos  \
# 0        October  Wednesday  2014 -1.000000 -1.836970e-16  0.974928 -0.222521
# 1         August     Friday  2014 -0.500000 -8.660254e-01 -0.433884 -0.900969
# 2         August  Wednesday  2014 -0.500000 -8.660254e-01  0.974928 -0.222521
# 3          April   Saturday  2014  1.000000  6.123234e-17 -0.974928 -0.222521
# 4            May    Tuesday  2015  0.866025 -5.000000e-01  0.781831  0.623490
# ...          ...        ...   ...       ...           ...       ...       ...
# 26047       June     Sunday  2014  0.500000 -8.660254e-01 -0.781831  0.623490
# 26048     August     Sunday  2014 -0.500000 -8.660254e-01 -0.781831  0.623490
# 26049    January     Friday  2015  0.000000  1.000000e+00 -0.433884 -0.900969
# 26050  September     Sunday  2014 -0.866025 -5.000000e-01 -0.781831  0.623490
# 26051    October   Saturday  2013 -1.000000 -1.836970e-16 -0.974928 -0.222521
#
#       City Tier
# 0        Tier-1
# 1        Tier-3
# 2        Tier-1
# 3        Tier-3
# 4        Tier-1
# ...         ...
# 26047    Tier-1
# 26048    Tier-1
# 26049    Tier-1
# 26050    Tier-2
# 26051    Tier-1
#
# [26052 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26052 entries, 0 to 26051
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City       26052 non-null  object
#  1   Card Type  26052 non-null  object
#  2   Exp Type   26052 non-null  object
#  3   Gender     26052 non-null  object
#  4   Amount     26052 non-null  int64
#  5   Month      26052 non-null  int32
#  6   Day        26052 non-null  int32
#  7   MonthName  26052 non-null  object
#  8   DayName    26052 non-null  object
#  9   Year       26052 non-null  int32
#  10  MonthSin   26052 non-null  float64
#  11  MonthCos   26052 non-null  float64
#  12  DaySin     26052 non-null  float64
#  13  DayCos     26052 non-null  float64
#  14  City Tier  26052 non-null  object
# dtypes: float64(4), int32(3), int64(1), object(7)
# memory usage: 2.7+ MB

# %%
data.describe()
# Out:
#               Amount         Month           Day          Year      MonthSin  \
# count   26052.000000  26052.000000  26052.000000  26052.000000  26052.000000
# mean   156411.537425      6.354023      3.016621   2014.092392      0.025953
# std    103063.254287      3.739676      2.006111      0.620761      0.731166
# min      1005.000000      1.000000      0.000000   2013.000000     -1.000000
# 25%     77120.250000      3.000000      1.000000   2014.000000     -0.866025
# 50%    153106.500000      6.000000      3.000000   2014.000000      0.000000
# 75%    228050.000000     10.000000      5.000000   2014.000000      0.866025
# max    998077.000000     12.000000      6.000000   2015.000000      1.000000
#
#            MonthCos        DaySin        DayCos
# count  26052.000000  26052.000000  26052.000000
# mean       0.165944     -0.006499      0.001982
# std        0.661228      0.706793      0.707415
# min       -1.000000     -0.974928     -0.900969
# 25%       -0.500000     -0.781831     -0.900969
# 50%        0.500000      0.000000     -0.222521
# 75%        0.866025      0.781831      0.623490
# max        1.000000      0.974928      1.000000

# %%
data.head()
# Out:
#              City  Card Type Exp Type Gender  Amount  Month  Day MonthName  \
# 0           Delhi       Gold    Bills      F   82475     10    2   October
# 1  Greater Mumbai   Platinum    Bills      F   32555      8    4    August
# 2       Bengaluru     Silver    Bills      F  101738      8    2    August
# 3  Greater Mumbai  Signature    Bills      F  123424      4    5     April
# 4       Bengaluru       Gold    Bills      F  171574      5    1       May
#
#      DayName  Year  MonthSin      MonthCos    DaySin    DayCos City Tier
# 0  Wednesday  2014 -1.000000 -1.836970e-16  0.974928 -0.222521    Tier-1
# 1     Friday  2014 -0.500000 -8.660254e-01 -0.433884 -0.900969    Tier-3
# 2  Wednesday  2014 -0.500000 -8.660254e-01  0.974928 -0.222521    Tier-1
# 3   Saturday  2014  1.000000  6.123234e-17 -0.974928 -0.222521    Tier-3
# 4    Tuesday  2015  0.866025 -5.000000e-01  0.781831  0.623490    Tier-1

# %%
data['Amount'].hist()
# Out:
# <Axes: >

# %%
data = data[data['Amount'] < 300000]
data['Amount'].hist()
data.shape
# Out:
# (25754, 15)

# %%
import math

num_of_categories = 10;
max_amount = data['Amount'].max()
print(max_amount)
step_size = math.ceil((max_amount/num_of_categories)/10000)*10000
print(step_size)
# Out:
# 299981
# 30000

# %%
def catergorize_amount(value):
    amount_cat = None
    for i in range(1,num_of_categories+1):
        thresh = i*step_size
        if(value > thresh):
            pass
        else:
            amount_cat = f"{thresh-step_size} - {thresh}"
            return amount_cat

# %%
data['Amount_Category']= data['Amount'].apply(catergorize_amount)
# Out:
# /tmp/ipykernel_33/573246793.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amount_Category']= data['Amount'].apply(catergorize_amount)

# %%
print(data[["Amount", "Amount_Category"]].head(10))
# Out:
#    Amount  Amount_Category
# 0   82475    60000 - 90000
# 1   32555    30000 - 60000
# 2  101738   90000 - 120000
# 3  123424  120000 - 150000
# 4  171574  150000 - 180000
# 5  100036   90000 - 120000
# 6  143250  120000 - 150000
# 7  150980  150000 - 180000
# 8  192247  180000 - 210000
# 9   67932    60000 - 90000

# %%
columns_to_drop = ["Card Type","Day","Amount","Year","City", "Month", "MonthSin","MonthCos","DaySin" ,"DayCos","Amount_Category"]
data.drop(columns=columns_to_drop, inplace=True)
data.head()
# Out:
# /tmp/ipykernel_33/236507783.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop(columns=columns_to_drop, inplace=True)
#   Exp Type Gender MonthName    DayName City Tier
# 0    Bills      F   October  Wednesday    Tier-1
# 1    Bills      F    August     Friday    Tier-3
# 2    Bills      F    August  Wednesday    Tier-1
# 3    Bills      F     April   Saturday    Tier-3
# 4    Bills      F       May    Tuesday    Tier-1

# %%
import matplotlib.pyplot as plt
from kmodes.kmodes import KModes

# %%
data.head()
# Out:
#   Exp Type Gender MonthName    DayName City Tier
# 0    Bills      F   October  Wednesday    Tier-1
# 1    Bills      F    August     Friday    Tier-3
# 2    Bills      F    August  Wednesday    Tier-1
# 3    Bills      F     April   Saturday    Tier-3
# 4    Bills      F       May    Tuesday    Tier-1

# %%
print("Unique values in Exp Type: ", data['Exp Type'].unique())
print("Unique values in MonthName: ", data['MonthName'].unique())
print("Unique values in City Tier: ", data['City Tier'].unique())
print("Unique values in DayName: ", data['DayName'].unique())
print("Unique values in Gender: ", data['Gender'].unique())
# Out:
# Unique values in Exp Type:  ['Bills' 'Food' 'Entertainment' 'Grocery' 'Fuel' 'Travel']
# Unique values in MonthName:  ['October' 'August' 'April' 'May' 'September' 'February' 'June' 'March'
#  'December' 'July' 'November' 'January']
# Unique values in City Tier:  ['Tier-1' 'Tier-3' 'Tier-2']
# Unique values in DayName:  ['Wednesday' 'Friday' 'Saturday' 'Tuesday' 'Monday' 'Thursday' 'Sunday']
# Unique values in Gender:  ['F' 'M']

# %%
exp_type_encoding = {'Bills': 0, 'Food': 1, 'Entertainment': 2, 'Grocery': 3,
                     'Fuel': 4, 'Travel': 5}


month_encoding = { 'January': 0, 'February': 1, 'March': 2, 'April': 3, 
                  'May': 4, 'June': 5, 'July': 6, 'August': 7, 
                  'September': 8, 'October': 9, 'November': 10, 
                  'December': 11}

gender_encoding = {'F': 0, 'M': 1}

city_tier_encoding = {'Tier-1': 0, 'Tier-2': 1, 'Tier-3': 2}

day_encoding = { 'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 
                'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}

# %%
exp_type_decoding = {v: k for k, v in exp_type_encoding.items()}
month_decoding = {v: k for k, v in month_encoding.items()}
city_tier_decoding = {v: k for k, v in city_tier_encoding.items()}
day_decoding = {v: k for k, v in day_encoding.items()}
gender_decoding = {v: k for k, v in gender_encoding.items()}

# %%
def apply_encoding(series, encoding_dict):
    return series.map(encoding_dict)

data_encoded = data.copy()
data_encoded['Exp Type'] = apply_encoding(data['Exp Type'], exp_type_encoding)
data_encoded['MonthName'] = apply_encoding(data['MonthName'], month_encoding)
data_encoded['City Tier'] = apply_encoding(data['City Tier'], city_tier_encoding)
data_encoded['Gender'] = apply_encoding(data['Gender'], gender_encoding)
data_encoded['DayName'] = apply_encoding(data['DayName'], day_encoding)

data_encoded.head()
# Out:
#    Exp Type  Gender  MonthName  DayName  City Tier
# 0         0       0          9        2          0
# 1         0       0          7        4          2
# 2         0       0          7        2          0
# 3         0       0          3        5          2
# 4         0       0          4        1          0

# %%
data_encoded.describe()
# Out:
#            Exp Type        Gender     MonthName       DayName     City Tier
# count  25754.000000  25754.000000  25754.000000  25754.000000  25754.000000
# mean       2.095480      0.480391      5.356372      3.014561      0.822979
# std        1.484752      0.499625      3.740366      2.006044      0.911873
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      0.000000      2.000000      1.000000      0.000000
# 50%        2.000000      0.000000      5.000000      3.000000      0.000000
# 75%        3.000000      1.000000      9.000000      5.000000      2.000000
# max        5.000000      1.000000     11.000000      6.000000      2.000000

# %%
data_matrix = data_encoded.to_numpy()

# %%
data_matrix
# Out:
# array([[0, 0, 9, 2, 0],
#        [0, 0, 7, 4, 2],
#        [0, 0, 7, 2, 0],
#        ...,
#        [5, 1, 0, 4, 0],
#        [5, 1, 8, 6, 1],
#        [0, 1, 9, 5, 0]])

# %%
cost = []
K = range(1, 30)

for num_clusters in K:
    print(num_clusters)
    kmodes = KModes(n_clusters=num_clusters, init='Huang', n_init=5, verbose=1)
    kmodes.fit_predict(data_matrix)
    cost.append(kmodes.cost_)

# Plot the cost against the number of clusters
plt.figure(figsize=(8, 4))
plt.plot(K, cost, 'bx-')
plt.xlabel('Number of clusters')
plt.ylabel('Cost')
plt.title('Elbow Method For Optimal k')
plt.show()
# Out:
# 1
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 90079.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 90079.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 90079.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 90079.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 90079.0
# Best run was number 1
# 2
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 2487, cost: 76567.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2848, cost: 77204.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 2048, cost: 75884.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1714, cost: 76949.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 82500.0
# Best run was number 3
# 3
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 7764, cost: 71657.0
# Run 1, iteration: 2/100, moves: 410, cost: 71657.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 72642.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 69716.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1726, cost: 72797.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 3904, cost: 71578.0
# Best run was number 3
# 4
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 72598.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 68610.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 5659, cost: 67646.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 69928.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 72959.0
# Best run was number 3
# 5
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 66199.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2473, cost: 64520.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 653, cost: 65361.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 65862.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 65691.0
# Best run was number 2
# 6
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3241, cost: 62276.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 1271, cost: 65154.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 4589, cost: 63775.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2130, cost: 65283.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 4559, cost: 63656.0
# Best run was number 1
# 7
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 61359.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 61072.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 61414.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 62667.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 62432.0
# Best run was number 2
# 8
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 58949.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 3154, cost: 60472.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1288, cost: 60572.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 60385.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 58789.0
# Best run was number 5
# 9
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3925, cost: 58225.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 3078, cost: 58737.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 57215.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 58006.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 57934.0
# Best run was number 3
# 10
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 1380, cost: 54963.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 55891.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 58512.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 58211.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1083, cost: 55657.0
# Best run was number 1
# 11
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 3547, cost: 54444.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2380, cost: 56155.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 56760.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 56810.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 56743.0
# Best run was number 1
# 12
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 57222.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 4142, cost: 55111.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 53546.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 2497, cost: 56360.0
# Run 4, iteration: 2/100, moves: 209, cost: 56360.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 55225.0
# Best run was number 3
# 13
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 54412.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 53763.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 53480.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 54842.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 651, cost: 55182.0
# Best run was number 3
# 14
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 53524.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 53821.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 52023.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 53473.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 53588.0
# Best run was number 3
# 15
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 51080.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 2798, cost: 53084.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 52743.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1056, cost: 51343.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 1177, cost: 51020.0
# Best run was number 5
# 16
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 51465.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 52710.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1269, cost: 51538.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 51469.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 52108.0
# Best run was number 1
# 17
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 50271.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 50239.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 49436.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 51882.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 49626.0
# Best run was number 3
# 18
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 50399.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 49163.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 50242.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 50134.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 50329.0
# Best run was number 2
# 19
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 48577.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 49646.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 1668, cost: 49205.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 49547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 48801.0
# Best run was number 1
# 20
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 865, cost: 48793.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 50323.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 48177.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 50796.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 48138.0
# Best run was number 5
# 21
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 48594.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 48091.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 48138.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 48656.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 49402.0
# Best run was number 2
# 22
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 577, cost: 48637.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 46957.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 49379.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 47775.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 46884.0
# Best run was number 5
# 23
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 48109.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 573, cost: 47571.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 667, cost: 47244.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1748, cost: 48321.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 49047.0
# Best run was number 3
# 24
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 362, cost: 47032.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 47231.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 47714.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1071, cost: 47547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 47283.0
# Best run was number 1
# 25
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 46825.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 45912.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 492, cost: 46134.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 45600.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 46685.0
# Best run was number 4
# 26
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 46057.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 45944.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 45901.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 1048, cost: 45599.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 178, cost: 45503.0
# Best run was number 5
# 27
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 44925.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 607, cost: 46570.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 44812.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 739, cost: 46314.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 618, cost: 45510.0
# Best run was number 3
# 28
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 45639.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 45629.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 45657.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 513, cost: 45975.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 44648.0
# Best run was number 5
# 29
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 428, cost: 45716.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 45078.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 45683.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 44957.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 45648.0
# Best run was number 4

# %%
best_k = 6
kmodes = KModes(n_clusters=best_k, init='Huang', n_init=5, verbose=1)
clusters = kmodes.fit_predict(data_matrix)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 6117, cost: 61838.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 0, cost: 63610.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 4620, cost: 63103.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 5253, cost: 62092.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 62046.0
# Best run was number 1

# %%
cluster_centroids = kmodes.cluster_centroids_
for i, centroid in enumerate(cluster_centroids):
    print(f"Cluster {i}: {centroid}")
# Out:
# Cluster 0: [2 1 3 5 0]
# Cluster 1: [2 0 8 5 2]
# Cluster 2: [1 1 2 3 0]
# Cluster 3: [1 0 3 4 0]
# Cluster 4: [0 0 0 6 0]
# Cluster 5: [ 3  1 10  1  0]

# %%
def decode_cluster_centroids(cluster_centroids, decoding_dicts):
    decoded_centroids = []
    for centroid in cluster_centroids:
        decoded_values = []
        for i, code in enumerate(centroid):
            decoded_values.append(decoding_dicts[i][code])
        decoded_centroids.append(decoded_values)
    return decoded_centroids

decoded_centroids = decode_cluster_centroids(cluster_centroids, [
    exp_type_decoding, gender_decoding, month_decoding , day_decoding , city_tier_decoding
])

for i, centroid in enumerate(decoded_centroids):
    print(f"Cluster {i}: {centroid}")
# Out:
# Cluster 0: ['Entertainment', 'M', 'April', 'Saturday', 'Tier-1']
# Cluster 1: ['Entertainment', 'F', 'September', 'Saturday', 'Tier-3']
# Cluster 2: ['Food', 'M', 'March', 'Thursday', 'Tier-1']
# Cluster 3: ['Food', 'F', 'April', 'Friday', 'Tier-1']
# Cluster 4: ['Bills', 'F', 'January', 'Sunday', 'Tier-1']
# Cluster 5: ['Grocery', 'M', 'November', 'Tuesday', 'Tier-1']

# %%
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(data_matrix, clusters, metric='euclidean')
print(f'Silhouette Score: {silhouette_avg}')
# Out:
# Silhouette Score: -0.04791369909351588

# %%
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(cluster_centroids, annot=True, cmap='viridis', fmt='.2f', xticklabels=data.columns)
plt.title('Heatmap of Cluster Centroids')
plt.show()

# %%
from joblib import Parallel, delayed 
import joblib 
  
  
# Save the model as a pickle in a file 
joblib.dump(clusters, 'model_with_6_clusters_without_price.pkl') 
  
# Load the model from the file 
# knn_from_joblib = joblib.load('filename.pkl') 
  
# Use the loaded model to make predictions 
# knn_from_joblib.predict(X_test)
# Out:
# ['model_with_6_clusters_without_price.pkl']

# %%
best_k = 10
kmodes = KModes(n_clusters=best_k, init='Huang', n_init=5, verbose=1)
clusters = kmodes.fit_predict(data_matrix)
cluster_centroids = kmodes.cluster_centroids_
for i, centroid in enumerate(cluster_centroids):
    print(f"Cluster {i}: {centroid}")
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 0, cost: 56553.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 955, cost: 58547.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 0, cost: 56091.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 0, cost: 56067.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 0, cost: 56017.0
# Best run was number 5
# Cluster 0: [3 0 0 1 0]
# Cluster 1: [3 0 1 2 0]
# Cluster 2: [0 0 4 4 0]
# Cluster 3: [4 1 1 3 2]
# Cluster 4: [4 0 1 4 1]
# Cluster 5: [2 1 7 2 0]
# Cluster 6: [3 1 0 5 0]
# Cluster 7: [0 0 9 4 2]
# Cluster 8: [1 0 3 1 0]
# Cluster 9: [1 1 9 4 0]

# %%
def decode_cluster_centroids(cluster_centroids, decoding_dicts):
    decoded_centroids = []
    for centroid in cluster_centroids:
        decoded_values = []
        for i, code in enumerate(centroid):
            decoded_values.append(decoding_dicts[i][code])
        decoded_centroids.append(decoded_values)
    return decoded_centroids

decoded_centroids = decode_cluster_centroids(cluster_centroids, [
    exp_type_decoding, gender_decoding, month_decoding , day_decoding , city_tier_decoding
])

for i, centroid in enumerate(decoded_centroids):
    print(f"Cluster {i}: {centroid}")
    
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(data_matrix, clusters, metric='euclidean')
print(f'Silhouette Score: {silhouette_avg}')

import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(cluster_centroids, annot=True, cmap='viridis', fmt='.2f', xticklabels=data.columns)
plt.title('Heatmap of Cluster Centroids')
plt.show()
# Out:
# Cluster 0: ['Grocery', 'F', 'January', 'Tuesday', 'Tier-1']
# Cluster 1: ['Grocery', 'F', 'February', 'Wednesday', 'Tier-1']
# Cluster 2: ['Bills', 'F', 'May', 'Friday', 'Tier-1']
# Cluster 3: ['Fuel', 'M', 'February', 'Thursday', 'Tier-3']
# Cluster 4: ['Fuel', 'F', 'February', 'Friday', 'Tier-2']
# Cluster 5: ['Entertainment', 'M', 'August', 'Wednesday', 'Tier-1']
# Cluster 6: ['Grocery', 'M', 'January', 'Saturday', 'Tier-1']
# Cluster 7: ['Bills', 'F', 'October', 'Friday', 'Tier-3']
# Cluster 8: ['Food', 'F', 'April', 'Tuesday', 'Tier-1']
# Cluster 9: ['Food', 'M', 'October', 'Friday', 'Tier-1']
# Silhouette Score: -0.08823202519402377

# %%
from joblib import Parallel, delayed 
import joblib 
  
  
# Save the model as a pickle in a file 
joblib.dump(clusters, 'model_with_10_clusters_without_price.pkl') 
  
# Load the model from the file 
# knn_from_joblib = joblib.load('filename.pkl') 
  
# Use the loaded model to make predictions 
# knn_from_joblib.predict(X_test)
# Out:
# ['model_with_10_clusters_without_price.pkl']
